# %% [markdown]
# <a href="https://colab.research.google.com/github/hantae96/TIL-/blob/main/%EC%8B%A4%EC%8A%B53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class ArrayList:
  def __init__(self):
    self.items = []
    print("Enter a command  : i(nsert), d(elete), e(mtpy), g(etEntry), c(lear), a(dd) \ndup, remove,search, f(ind),r(eplace),s(ort),m(erge),p(rint):\n")
   
  def check(self):
    while True:
      self.command_set = list(input("> ").split())

      if self.command_set[0] == "q":
        break
      
      elif self.command_set[0] == "a":
        self.elem = self.command_set[1]
        self.add(self.elem)
      elif self.command_set[0] == "i":
        self.pos = int(self.command_set[1])
        self.elem = self.command_set[2]
        self.insert(self.pos,self.elem)
      elif self.command_set[0] == "d":
        self.pos = self.command_set[1]
        self.item.pop(pos)
      elif self.command_set[0] == "e":
        self.empty()
      elif self.command_set[0] == "g":
        self.pos=int(self.command_set[1])
        self.getEntry(self.pos)
      elif self.command_set[0] == "c":
        self.clear()
      elif self.command_set[0] == "f":
        self.items=self.command_set[1]
        self.find()
      elif self.command_set[0] == "r":
        self.pos = int(self.command_set[1])
        self.elem = int(self.command_set[2])
        self.replace(self.pos,self.elem)
      elif self.command_set[0] == "s":
        self.sort()
      elif self.command_set[0] == "p":
        self.print()
      elif self.command_set[0] == "remove":
        self.elem=self.command_set[1]
        self.remove(self.elem)
      elif self.command_set[0] == "search":
        self.elem=self.command_set[1]
        self.search(self.elem)
      elif self.command_set[0] == "dup":
        self.dup(self.items)
      elif self.command_set[0] == "m":
        self.lst = self.command_set[1:]
        self.merge(self.lst)

  def add(self,elem):
    self.items.append(self.elem)
  def remove(self,elem):
    if self.elem in self.items: 
      self.items.remove(self.elem)
      print(f"{self.elem} removed")
    else : print("No such element")
  def insert(self,pos,elem):
    self.items.insert(self.pos,self.elem)
  def delete(self,pos):
    return self.items.pop(self.pos)
  def empty(self):
    if len(self.items)==0:
      return print(True)
    else:
      return print(False)
  def getEntry(self,pos):
    return print(self.items[self.pos])
  def size(self):
    return len(self.items)
  def clear(self):
    return self.items.clear()
  def find(self,items):
    return self.items.index(self.items)
  def replace(self,pos,elem):
    self.items[self.pos] = self.elem
    return self.items
  def search(self,elem):
    if self.elem in self.items: print(f"{self.elem}  found")
    else : print(f"No such element")
  def dup(self,items):
    self.dup_set = []
    for i in self.items:
      if i not in self.dup_set:
        self.dup_set.append(i)
        #print(self.dup_set)
        self.items=self.dup_set
    return self.items
  def sort(self):
    return self.items.sort()
  def merge(self,lst):
    return self.items.extend(self.lst)
  def size(self):
    return len(self.items)
  def print(self,msg = "ArrayList"):
    print(f"ArrayList {self.size()} {self.items}")

key=ArrayList()
key.check()
# Out:
# Enter a command  : i(nsert), d(elete), e(mtpy), g(etEntry), c(lear), a(dd)
# dup, remove,search, f(ind),r(eplace),s(ort),m(erge),p(rint):
#
# > e 1
# True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# ...

# %%
command,num = input().split()
command,num

# %%
def dup(items):
    dup_set = []
    for i in items:
      if i not in dup_set:
        dup_set.append(i) 
    return dup_set
items=[10,10,20]
dup(items)

# %%
def myLineEditor():
  list = ArrayList()
  while True:
    command = input("[메뉴선택] i-입력,d-삭제,r-변경,p-출력,l-파일읽기,s-저장,q-종료 =>")
    if command = "i":
      pos = int(input("입력 행 번호 : "))
      str = input("입력행 내용 :")
      list.insert(pos,str)
    elif if command = "d":
      pos = int(input("삭제행 번호 : "))
      list.delete(pos)
    elif if command = "r":
      pos = int(input("변경행 번호 : "))
      str = input("변경행 내용 :")
      list.replace(pos,str)
    elif command == 'q' : return
    elif if command == "p":
      print('Line Editor')
      for lin in range(list.size())
      print('[%2d]' )

# %%
class ArrayList:
  def __init__(self):
    self.text = []
    self.text = open("/content/input.txt",'r',encoding='cp949')
    self.lines = self.text.readlines()
    for i in self.lines:
      print(i)

    #print(lines)

  def check(self):
    while True:
      self.command_set = list(input("> ").split())

      if self.command_set[0] == "q":
        break
      
      elif self.command_set[0] == "a":
        self.elem = self.command_set[1]
        self.add(self.elem)
      elif self.command_set[0] == "i":
        self.pos = self.command_set[1]
        #x = input("입력 : ")
        self.string = input()
        self.insert(self.pos,self.string)
      elif self.command_set[0] == "d":
        self.pos = self.command_set[1]
        self.item.pop(pos)
      elif self.command_set[0] == "e":
        self.empty()
      elif self.command_set[0] == "g":
        self.pos=int(self.command_set[1])
        self.getEntry(self.pos)
      elif self.command_set[0] == "c":
        self.clear()
      elif self.command_set[0] == "f":
        self.items=self.command_set[1]
        self.find()
      elif self.command_set[0] == "r":
        self.pos = int(self.command_set[1])
        self.elem = int(self.command_set[2])
        self.replace(self.pos,self.elem)
      elif self.command_set[0] == "s":
        self.sort()
      elif self.command_set[0] == "p":
        self.print()
      elif self.command_set[0] == "remove":
        self.elem=self.command_set[1]
        self.remove(self.elem)
      elif self.command_set[0] == "search":
        self.elem=self.command_set[1]
        self.search(self.elem)
      elif self.command_set[0] == "dup":
        self.dup(self.items)
      elif self.command_set[0] == "m":
        self.lst = self.command_set[1:]
        self.merge(self.lst)

  def add(self,elem):
    self.items.append(self.elem)
  def remove(self,elem):
    if self.elem in self.items: 
      self.items.remove(self.elem)
      print(f"{self.elem} removed")
    else : print("No such element")
  def insert(self,pos,string):   
    self.lines.insert(self.pos,self.string)
  def delete(self,pos):
    return self.items.pop(self.pos)
  def empty(self):
    if len(self.items)==0:
      return print(True)
    else:
      return print(False)
  def getEntry(self,pos):
    return print(self.lines[self.pos])
  def size(self):
    return len(self.lines)
  def clear(self):
    return self.items.clear()
  def find(self,items):
    return self.items.index(self.items)
  def replace(self,pos,elem):
    self.items[self.pos] = self.elem
    return self.items
  def search(self,elem):
    if self.elem in self.items: print(f"{self.elem}  found")
    else : print(f"No such element")
  def dup(self,items):
    self.dup_set = []
    for i in self.items:
      if i not in self.dup_set:
        self.dup_set.append(i)
        #print(self.dup_set)
        self.items=self.dup_set
    return self.items
  def sort(self):
    return self.items.sort()
  def merge(self,lst):
    return self.items.extend(self.lst)
  def size(self):
    return len(self.lines)
  def print(self):
    self.lines = self.text.readlines()
    for i in lines:
      print(i)
      
lst = ArrayList()
lst.check()

f = open("/content/input.txt",'r',encoding='cp949')
lines = f.readlines()

print(lines)

# %%
class ArrayList:
  def __init__(self):
    self.lines = []
    self.text = open("/content/input.txt",'r',encoding='cp949')
    self.lines = self.text.readlines()
    self.lines2=[]
    for i in self.lines:
      self.lines2.append(i.rstrip("\n"))

    for i in range(len(self.lines2)):
      print(f"{int(i)+1}>{self.lines2[i]}")

  def delete(self,pos,pos2):
    return self.lines2.pop(self.pos)
    return self.lines2.pop(self.pos2)

  def insert(self,pos,string):  # 인자에
    self.pos=int(self.pos)-1
    self.lines2.insert(self.pos,self.string)

  def replace(self,pos,elem):
    self.lines2[self.pos-1] = self.elem
    return self.lines2

  def print(self):
    for i in self.lines2:
      print(i,end="")
 

  def check(self):

    while True:
      self.command_set = list(input("> ").split())
      if self.command_set[0] == "i":
        self.pos = self.command_set[1]
        self.A = []
        while True:
          self.string = input() 
          if self.string == "*":
            break
          else :
            self.A.append(self.string) 
        
        for i in range(len(self.A)):
          self.lines2.insert(int(self.pos)-1+i,self.A[i])

      elif self.command_set[0] == "q":
        break

      elif self.command_set[0] == "d":
        self.pos = int(self.command_set[1])
        self.pos2 = int(self.command_set[2])
        del self.lines2[self.pos-1:self.pos2]
        #del self.lines[self.pos2]
        

      elif self.command_set[0] == "r":
        self.pos = int(self.command_set[1])
        self.elem = input()
        self.replace(self.pos,self.elem)

      elif self.command_set[0] == "p":
        for i in range(len(self.lines2)):
          print(f"{int(i)+1}>{self.lines2[i]}")


key=ArrayList()
key.check()
# Out:
# 1>		꽃
# 2>
# 3>			  김춘수
# 4>
# 5>내가 그의 이름을 불러 주기 전에는
# 6>그는 다만 하나의 몸짓에 지나지 않았다.
# 7>
# 8>내가 그의 이름을 불러 주었을 때
# 9>그는 나에게로 와서 꽃이 되었다.
# 10>
# 11>내가 그의 이름을 불러 준 것처럼
# 12>나의 이 빛깔과 향기(香氣)에 알맞는
# 13>누가 나의 이름을 불러다오.
# 14>그에게로 가서 나도
# 15>그의 꽃이 되고 싶다
# 16>
# 17>우리들은 모두 무엇이 되고 싶다.
# 18>너는 나에게 나는 너에게
# 19>잊혀지지 않는 하나의 눈짓이 되고 싶다.
# > i 16
# 그에게로 가서 나도
# 그의 꽃이 되고 싶다.
# *
# > p
# 1>		꽃
# 2>
# 3>			  김춘수
# 4>
# 5>내가 그의 이름을 불러 주기 전에는
# 6>그는 다만 하나의 몸짓에 지나지 않았다.
# 7>
# 8>내가 그의 이름을 불러 주었을 때
# 9>그는 나에게로 와서 꽃이 되었다.
# 10>
# 11>내가 그의 이름을 불러 준 것처럼
# 12>나의 이 빛깔과 향기(香氣)에 알맞는
# 13>누가 나의 이름을 불러다오.
# 14>그에게로 가서 나도
# 15>그의 꽃이 되고 싶다
# 16>그에게로 가서 나도
# 17>그의 꽃이 되고 싶다.
# 18>
# 19>우리들은 모두 무엇이 되고 싶다.
# 20>너는 나에게 나는 너에게
# 21>잊혀지지 않는 하나의 눈짓이 되고 싶다.
# > d 14 15
# > p
# 1>		꽃
# 2>
# 3>			  김춘수
# 4>
# 5>내가 그의 이름을 불러 주기 전에는
# 6>그는 다만 하나의 몸짓에 지나지 않았다.
# 7>
# 8>내가 그의 이름을 불러 주었을 때
# 9>그는 나에게로 와서 꽃이 되었다.
# 10>
# 11>내가 그의 이름을 불러 준 것처럼
# 12>나의 이 빛깔과 향기(香氣)에 알맞는
# 13>누가 나의 이름을 불러다오.
# 14>그에게로 가서 나도
# 15>그의 꽃이 되고 싶다.
# 16>
# ...

# %%
class Set:
  def __init__(self):
    self.items = []
  #구현해야할 멤버 함수
  def __eq__(self,setB):
    self.items==setB
    return self.items == setB
  def __str__(self):
    return str(self.items)  #list 형태를 str로 출력하고싶은데 안되니까 str로 감싼다.
  def insert(self,elem):
    if elem not in self.items:
      self.elem=elem
      self.items.append(self.elem)

  def delete(self,elem):
    if self.elem in self.items:
      self.items.remove(self.elem)

#setA.union(setB)
  def union(self,setB):
    self.setA =setA()
    self.setC =set()
    setA.union(setB) 

'''
    for i in list(self.items):
      for j in self.a:
        if i != j:
          self.setC.append(j)
      #if i not in list(self.setB):

      #  self.setC.append(i)
    #return self.setC

  def intersect(self,setB):
    setC = set()
    for self.elem in setB.items:
      if self.elem in self.items:
        setC.self.items.append(self.elem)

  def difference(self,setB):
    setC=set()
    for self.setA in self.items:
      if self.setA not in setB.items:
        setC.items.append(setA)
    return setC


  def isSubset(self,setB):pass
    
  def isProperSubset(self,setB):pass

  def size(self):pass

  def print(self,msg):pass
'''
def test(setA,setB):
  print("SetA : ",setA)
  print("SetB : ",setB)
  if setA == setB:
    print("A equal B : True")
  else:
    print("A equal B : False")   
  #print("A subset B: ",setA,isSubset(setB))
  #print("A proper subset B: ",setA.isProperSubset(setB))
  print("A union B: ",setA.union(setB))
  #print("A union B: ",setA.intersect(setB))
  print("A difference B: ",setA.difference(setB))
  #print()

def main():
  setA = Set()
  setA.insert(2)
  setA.insert(3)
  setA.insert(4)

  setB=Set()
  setB.insert(2)
  setB.insert(3)
  setB.insert(4)

  setC=Set()
  setC.insert(2)
  setC.insert(3)
  setC.insert(4)
  setC.insert(4)

  test(setA,setB)
  test(setA,setC)
  test(setC,setA)

main()
# Out:
# SetA :
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-3515ffb90873> in <module>()
#      89   test(setC,setA)
#      90
# ---> 91 main()
#
# <ipython-input-78-3515ffb90873> in main()
#      85   setC.insert(4)
#      86
# ---> 87   test(setA,setB)
#      88   test(setA,setC)
#      89   test(setC,setA)
#
# <ipython-input-78-3515ffb90873> in test(setA, setB)
#      55 '''
#      56 def test(setA,setB):
# ---> 57   print("SetA : ",setA)
#      58   print("SetB : ",setB)
#      59   if setA == setB:
#
# <ipython-input-78-3515ffb90873> in __str__(self)
#       8   def __str__(self):
#       9     #return str(self.items)  #list 형태를 str로 출력하고싶은데 안되니까 str로 감싼다.
# ---> 10     return print("A union B: ",self.setA.union(setB))
#      11   def insert(self,elem):
#      12     if elem not in self.items:
#
# AttributeError: 'Set' object has no attribute 'setA'

# %%
import copy

class Set:
  def __init__(self):
    self.items = []
  #구현해야할 멤버 함수
  def __eq__(self,setB):
    if self.items==setB.items:
      return True
    else:
      return False

  def add(self,elem):
    self.items.append(self.elem)

  def __str__(self):
    return str(self.items)  #list 형태를 str로 출력하고싶은데 안되니까 str로 감싼다.
  def insert(self,elem):
    if elem not in self.items:
      self.elem=elem
      return self.items.append(self.elem)

  def delete(self,elem):
    if self.elem in self.items:
      return self.items.remove(self.elem)
  
  def union(self,setB):
    self.setD =[]
    self.setD = copy.deepcopy(self.items)  #새로운 변수에 넣기
    for i in setB.items:    #setB의 원소 반복
       if i not in self.setD: #setB의 원소가 self.A의 item안에 없으면
        self.setD.append(i) 
    return self.setD
  def intersect(self,setB):
    
    setC = Set()
    for i in setB.items:  # 23이 나와야되는데 234가 나온다.
      if i in self.items:
        setC.items.append(i) 
    return setC

  def difference(self,setB):
    self.setD=[]
    for i in self.items:
      if i not in setB.items:
        self.setD.append(i)
    
    return self.setD
  
  def isSubset(self,setB):
    flag = 0
    for i in self.items:  
      if i in setB.items:
        flag+=1
    if flag == len(self.items):  
      return True
    else:
      return False        
    
  def isProperSubset(self,setB):
    self.setD=[0]
    if self.isSubset(setB):
      if len(self.items) != len(setB.items):
        return True
      else:
        return False
    else:
      return False

  def size(self):
    length=len(self.items)
    return length

  def print(self,msg):
    print(self.items)


def test(setA,setB):
  print("SetA : ",setA)
  print("SetB : ",setB)
  if setA == setB:
    print("A equal B : True")
  else:
    print("A equal B : False")   
  
  print("A subset B: ",setA.isSubset(setB))
  print("A proper subset B: ",setA.isProperSubset(setB))
  print("A union B: ",setA.union(setB))
  print("A intersect B: ",setA.intersect(setB))
  print("A difference B: ",setA.difference(setB))
  print()

def main():
  setA = Set()
  setA.insert(2)
  setA.insert(3)
  setA.insert(4)

  setB=Set()
  setB.insert(2)
  setB.insert(3)
  setB.insert(4)

  setC=Set()
  setC.insert(2)
  setC.insert(3)
  setC.insert(4)
  setC.delete(4)

  test(setA,setB)
  test(setA,setC)
  test(setC,setA)

main()
# Out:
# SetA :  [2, 3, 4]
# SetB :  [2, 3, 4]
# A equal B : True
# A subset B:  True
# A proper subset B:  False
# A union B:  [2, 3, 4]
# A intersect B:  [2, 3, 4]
# A difference B:  []
#
# SetA :  [2, 3, 4]
# SetB :  [2, 3]
# A equal B : False
# A subset B:  False
# A proper subset B:  False
# A union B:  [2, 3, 4]
# A intersect B:  [2, 3]
# A difference B:  [4]
#
# SetA :  [2, 3]
# SetB :  [2, 3, 4]
# A equal B : False
# A subset B:  True
# A proper subset B:  True
# A union B:  [2, 3, 4]
# A intersect B:  [2, 3]
# A difference B:  []

# %%
def __eq__(self, setB):
        if len(self.items) == len(setB.items) and self.items.sort() == setB.items.sort():
            return True
        else:
            return False

# %%
test_C = [2,3]
test_A = [2,3,4]

for i in test_C:
  if i in test_A:
    print(i)
# Out:
# 2
# 3

# %%
  def intersect(self,setB):
    self.setD =[]
    self.setC = self.items  #setC.itmes (2,3)  
    for i in self.setC:    #23 반복
       if i in setB.items: # 234
          self.setD.append(i) 
    return self.setD
